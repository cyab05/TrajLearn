# %% [markdown]
# # Running TrajLearn in Colab
# Start by connecting the kernel to Colab and a GPU T4, then run these commands

# %%
# install conda colab
# %pip install -q condacolab

# %% [markdown]
# Start by setting up conda. After running below command, kernel will automatically restart. Run it again, then it should print `✨🍰✨ Everything looks OK!`.

# %%
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# ## Download data

# %% [markdown]
# Next we mount our Google Drive so the script can access the data folder. This code will prompt you to sign in. Do it, then come back to VS code and click continue

# %%
# mount drive so colab can access data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Copy it to local, and make sure you config file is pointing to ../

# %%
# Copy the entire folder from Drive to local storage
# !cp -r /content/drive/MyDrive/botswana7/ /content/botswana7/

# %% [markdown]
# Now we clone the repo and set up our conda env

# %%
# 1. Clone your repository into the Colab environment
# !git clone https://github.com/cyab05/TrajLearn.git
# Out:
# Cloning into 'TrajLearn'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 62 (delta 19), reused 53 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (62/62), 8.81 MiB | 13.13 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
# 2. Cd to Trajlearn
# %cd TrajLearn
# Out:
# /content/TrajLearn

# %%
# 3. ensure you are in TrajLearn
# %ls
# Out:
# baselines/                 download_data.sh*   main.py
# botswana7_config.yaml      environment.yml     README.md
# botswana7_gpu_config.yaml  img/                rome7_config.yaml
# configs.yaml               kenya7_config.yaml  TrajLearn/
# data_preprocessing/        LICENSE

# %%
# create conda env, the should take about 4 minutes
# !conda env create -f environment.yml
# Out:
# ...
# Channels:
#  - defaults
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 26.3.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# python-3.10.20       | 24.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
# openssl-3.5.6        | 5.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# libstdcxx-15.2.0     | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# tk-8.6.15            | 3.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# setuptools-82.0.1    | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# sqlite-3.51.2        | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# pip-26.0.1           | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# ncurses-6.5          | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 895 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ...

# %%
# pull
# !git pull
# Out:
# Already up to date.

# %% [markdown]
# ## Run the Training
#
# Check the the config file is up to date before running

# %% [markdown]
# took almost 2 hours on first run

# %%
# !conda run --no-capture-output -n trajlearn python main.py botswana7_gpu_config.yaml
# Out:
# 2026-04-29 19:14:50 [INFO] [trainer.py:116]: Starting training
#   3% 99/3601 [00:17<09:22,  6.22it/s, loss=0.0115]2026-04-29 19:15:08 [INFO] [trainer.py:179]: Warm-up iterations ended, starting cosine decay
# Traceback (most recent call last):
#   File "/content/TrajLearn/main.py", line 45, in <module>
#     main()
#   File "/content/TrajLearn/main.py", line 41, in main
#     train_model(name, dataset, config, model)
#   File "/content/TrajLearn/TrajLearn/utils.py", line 146, in train_model
#     trainer.train()
#   File "/content/TrajLearn/TrajLearn/trainer.py", line 131, in train
#     _, loss = self.model(X.to(self.device), Y.to(self.device))
# KeyboardInterrupt
#
# CondaError: KeyboardInterrupt

# %%
# !conda run --no-capture-output -n trajlearn python main.py botswana7_gpu_config.yaml --test
# Out:
# 2026-04-28 21:46:06 [INFO] [evaluator.py:139]: Dataset: botswana7, Accuracy@1: 0.0334, Accuracy@3: 0.0334, Accuracy@5: 0.0334, BLEU score: 0.0011, Test duration: 68.556(s), Samples: 8995
